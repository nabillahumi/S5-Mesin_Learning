# %% [markdown]
# <a href="https://colab.research.google.com/github/nabillahumi/S5-Mesin_Learning/blob/main/Jobsheet3/Tugas%20Praktikum%20JS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Deskripsi Tugas
# Pada tugas pratikum ini Anda akan menggunakan data "Wisconsin Breast Cancer". Data tersebut terdiri dari 569 data yang digunakan untuk mendiagnonis jenis kanker Malignant (M) dan Benign (B). Tugas Anda adalah,

# %% [markdown]
# 1. Pisahkan antara variabel yang dapat digunakan dan variabel yang tidak dapat digunakan.

# %%
import pandas as pd

# 1. Load dataset
df = pd.read_csv('wbc.csv')

# 2. Hapus kolom yang tidak terpakai
df_clean = df.drop(columns=['id', 'Unnamed: 32'], errors='ignore')

# Cek kolom tersisa
print("Daftar kolom yang digunakan:")
print(df_clean.columns.tolist())
# Out:
# Daftar kolom yang digunakan:
# ['diagnosis', 'radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'compactness_mean', 'concavity_mean', 'concave points_mean', 'symmetry_mean', 'fractal_dimension_mean', 'radius_se', 'texture_se', 'perimeter_se', 'area_se', 'smoothness_se', 'compactness_se', 'concavity_se', 'concave points_se', 'symmetry_se', 'fractal_dimension_se', 'radius_worst', 'texture_worst', 'perimeter_worst', 'area_worst', 'smoothness_worst', 'compactness_worst', 'concavity_worst', 'concave points_worst', 'symmetry_worst', 'fractal_dimension_worst']

# %% [markdown]
# 2. Lakukan proses encoding pada kolom "diagnosis".

# %%
from sklearn.preprocessing import LabelEncoder

# 1. Inisialisasi LabelEncoder
le = LabelEncoder()

# 2. Fit dan transform kolom diagnosis
df_clean['diagnosis'] = le.fit_transform(df_clean['diagnosis'])

# 3. Pisahkan antara fitur (X) dan label target (y)
X = df_clean.drop(columns=['diagnosis'])
y = df_clean['diagnosis']

print("Mapping Label:", dict(zip(le.classes_, le.transform(le.classes_))))
print("Jumlah data per kelas:")
print(y.value_counts())
# Out:
# Mapping Label: {np.float64(nan): np.int64(0)}
# Jumlah data per kelas:
# diagnosis
# 0    569
# Name: count, dtype: int64

# %% [markdown]
# 3. Lakukan proses standarisasi pada semua kolom yang memiliki nilai numerik.

# %%
from sklearn.preprocessing import StandardScaler

# Inisialisasi dan lakukan standarisasi pada seluruh fitur numerik (X)
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

print("Tampilan 5 baris pertama fitur setelah di-standarisasi:")
display(X_scaled.head())
# Out:
# Tampilan 5 baris pertama fitur setelah di-standarisasi:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     1.097064     -2.073335        1.269934   0.984375         1.568466
# 1     1.829821     -0.353632        1.685955   1.908708        -0.826962
# 2     1.579888      0.456187        1.566503   1.558884         0.942210
# 3    -0.768909      0.253732       -0.592687  -0.764464         3.283553
# 4     1.750297     -1.151816        1.776573   1.826229         0.280372
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0          3.283515        2.652874             2.532475       2.217515
# 1         -0.487072       -0.023846             0.548144       0.001392
# 2          1.052926        1.363478             2.037231       0.939685
# 3          3.402909        1.915897             1.451707       2.867383
# 4          0.539340        1.371011             1.428493      -0.009560
#
#    fractal_dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0                2.255747  ...      1.886690      -1.359293         2.303601
# 1               -0.868652  ...      1.805927      -0.369203         1.535126
# 2               -0.398008  ...      1.511870      -0.023974         1.347475
# 3                4.910919  ...     -0.281464       0.133984        -0.249939
# 4               -0.562450  ...      1.298575      -1.466770         1.338539
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0    2.001237          1.307686           2.616665         2.109526
# 1    1.890489         -0.375612          -0.430444        -0.146749
# 2    1.456285          0.527407           1.082932         0.854974
# 3   -0.550021          3.394275           3.893397         1.989588
# 4    1.220724          0.220556          -0.313395         0.613179
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0              2.296076        2.750622                 1.937015
# 1              1.087084       -0.243890                 0.281190
# 2              1.955000        1.152255                 0.201391
# 3              2.175786        6.046041                 4.935010
# 4              0.729259       -0.868353                -0.397100
#
# [5 rows x 30 columns]

# %% [markdown]
# 4. Lakukan proses stratified split data untuk membuat data latih dan data uji dengan rasio 80:20.

# %%
from sklearn.model_selection import train_test_split

# Split data 80% train dan 20% test
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42, stratify=y
)

print(f"Dimensi Data Latih (X_train) : {X_train.shape}")
print(f"Dimensi Data Uji   (X_test)  : {X_test.shape}")
# Out:
# Dimensi Data Latih (X_train) : (455, 30)
# Dimensi Data Uji   (X_test)  : (114, 30)
